# %% [markdown]
# 1.	Your team number and your group members names in comments.
# 2.	Question/Story: What are you trying to show and why?
# 3.	Data Choices: Which tickers/series and time span, and why?
# 4.	Takeaway (2–3 sentences): What should a reader notice?

# %%
# Team 14
# Conner, Tai, Julia
# We are using the yfinance library to get stock data from Yahoo Finance

# import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf

# Tickers: Apple (AAPL), Gold (GC=F)
# Time period: 5 years
tickers = ['AAPL', 'GC=F']
df = yf.download(tickers, period='5y', group_by='ticker')

# We will be using the data to analyze the stock prices and make predictions
# Out:
# C:\Users\taitu\AppData\Local\Temp\ipykernel_58148\1386398458.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(tickers, period='5y', group_by='ticker')
# [*********************100%***********************]  2 of 2 completed

# %%
# Plotting
sns.set(rc={'axes.facecolor':'cornflowerblue', 'figure.facecolor':'cornflowerblue'})
plt.figure(figsize=(10, 6))
ax = sns.lineplot(data = df['AAPL'], x='Date', y='Close', linestyle='solid', label='Apple', color='#555555')
ax = sns.lineplot(data = df['GC=F'], x='Date', y='Close', linestyle='solid', label='Gold', color='gold')
plt.suptitle('Apple and Gold Index Price Trend Over Time')
plt.title('Data from Yahoo Finance API')
ax.set_xlabel('Year')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_ylabel('Price (USD)')
plt.line_style = ':'
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\taitu\AppData\Local\Temp\ipykernel_58148\106870637.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
